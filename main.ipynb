# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_ADD, GAS, 0)
evm_two = EVM(SIMPLE_SUB, GAS, 0)
evm_three = EVM(SIMPLE_MUL, GAS, 0)
evm_four = EVM(SIMPLE_DIV, GAS, 0)

# %%
evm.run()
evm_two.run()
evm_three.run()
evm_four.run()

# %%
print(evm.stack); print(evm_two.stack); print(evm_three.stack); print(evm_four.stack)
# Out:
# 321 <first
# 189 <first
