# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_ADD, GAS, 0)
evm_two = EVM(SIMPLE_SUB, GAS, 0)
evm_three = EVM(SIMPLE_MUL, GAS, 0)
evm_four = EVM(SIMPLE_DIV, GAS, 0)
evm_five = EVM(SIMPLE_SDIV, GAS, 0)
evm_six = EVM(SIMPLE_MOD, GAS, 0)
evm_seven = EVM(SIMPLE_SMOD, GAS, 0)
evm_eight = EVM(SIMPLE_ADDMOD, GAS, 0)
evm_nine = EVM(SIMPLE_MULMOD, GAS, 0)
evm_ten = EVM(SIMPLE_EXPONENT, GAS, 0)
evm_eleven = EVM(SIMPLE_SIGNEXTEND, GAS, 0)

# %%
evm.run()
evm_two.run()
evm_three.run()
evm_four.run()
evm_five.run()
evm_six.run()
evm_seven.run()
evm_eight.run()
evm_nine.run()
evm_ten.run()
evm_eleven.run()

# %%
print(evm.stack); print(evm_two.stack); print(evm_three.stack); print(evm_four.stack); print(evm_five.stack); print(evm_six.stack); print(evm_seven.stack); print(evm_eight.stack); print(evm_nine.stack); print(evm_ten.stack); print(evm_eleven.stack);
# Out:
# 321 <first
# 189 <first
# 16830 <first
# 3 <first
# 3 <first
# 57 <first
# 57 <first
# 1 <first
# 42 <first
# 73786976294838206464 <first
# 66 <first
