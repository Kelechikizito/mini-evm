# %%
# %run utils.ipynb

notebooks = [
    "stack.ipynb",
    "memory.ipynb",
    "storage.ipynb",
    "opcodes.ipynb",
    "opcodes/stop.ipynb",
    "opcodes/math.ipynb",
    "opcodes/comparisions.ipynb", 
    "opcodes/logic.ipynb",
    "opcodes/bit.ipynb",
    "opcodes/misc.ipynb",
    "opcodes/environment.ipynb",
    "opcodes/pop.ipynb",
    "opcodes/memory.ipynb",
    "opcodes/storage.ipynb",
    "opcodes/jump.ipynb",
    "opcodes/push.ipynb",
    "opcodes/dup.ipynb",
    "opcodes/swap.ipynb",
    "opcodes/log.ipynb",
    "opcodes/contract.ipynb",
    "opcodes/transient.ipynb",
]

import_notebooks(notebooks)
