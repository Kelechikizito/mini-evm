# %%
SIMPLE_ADD = [0x60, 0x42, 0x60, 0xFF, 0x01]

# %%
SIMPLE_PUSH = [0x60, 0x42]

# %%
SIMPLE_SUB = [0x60, 0x42, 0x60, 0xFF, 0x03]

# %%
SIMPLE_MUL = [0x60, 0x42, 0x60, 0xFF, 0x02]

# %%
SIMPLE_DIV = [0x60, 0x42, 0x60, 0xFF, 0x04]

# %%
SIMPLE_SDIV = [0x60, 0x42, 0x60, 0xFF, 0x05]

# %%
SIMPLE_MOD = [0x60, 0x42, 0x60, 0xFF, 0x06]

# %%
SIMPLE_SMOD = [0x60, 0x42, 0x60, 0xFF, 0x07]

# %%
SIMPLE_ADDMOD = [0x60, 0x42, 0x60, 0xFF, 0x60, 0xA, 0x08]

# %%
SIMPLE_MULMOD = [0x60, 0x42, 0x60, 0xFF, 0x60, 0xA, 0x09]

# %%
SIMPLE_EXPONENT = [0x60, 0x42, 0x60, 0x2, 0x0A]

# %%
SIMPLE_SIGNEXTEND = [0x60, 0x42, 0x60, 0xFF, 0x0B]
