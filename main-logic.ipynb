# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "logic-bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_AND, GAS, 0)
evm_two = EVM(SIMPLE_OR, GAS, 0)
evm_three = EVM(SIMPLE_XOR, GAS, 0)
evm_four = EVM(SIMPLE_NOT, GAS, 0)

# %%
evm.run()
evm_two.run()
evm_three.run()
evm_four.run()

# %%
print(evm.stack); print(evm_two.stack); print(evm_three.stack); print(evm_four.stack)
# Out:
# 66 <first
# 255 <first
# 189 <first
# -67 <first
