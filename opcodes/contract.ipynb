# %%
def create(evm):
    value, offset, size = evm.stack.pop(), evm.stack.pop(), evm.stack.pop()
    code = evm.memory.access(offset, size)
    # TODO: Implement contract creation logic
    
    evm.stack.push(address)
    evm.pc += 1
    evm.gas_dec(32000)

# def call(evm):

# def callcode(evm):

# def return(evm):

# def delegatecall(evm):

# def create2(evm):

# def staticcall(evm):

def revert(evm):
    offset, size = evm.stack.pop(), evm.stack.pop()
    evm.returndata = evm.memory.access(offset, size)

    evm.stop_flag = True
    evm.revert_flag = True
    evm.pc += 1
    evm.gas_dec(0)

# def invalid(evm):

def selfdetsruct(evm):
    address = evm.stack.pop()

    evm.stack.push(address.balance)
    evm.pc += 1
    evm.gas_dec()
