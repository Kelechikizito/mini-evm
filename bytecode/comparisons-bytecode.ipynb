# %%
SIMPLE_LT = [0x60, 0x42, 0x60, 0xFF, 0x10]
SIMPLE_GT = [0x60, 0x42, 0x60, 0xFF, 0x11]
SIMPLE_SLT = [0x60, 0x42, 0x60, 0xFF, 0x12]
SIMPLE_SGT = [0x60, 0x42, 0x60, 0xFF, 0x13]
SIMPLE_EQ = [0x60, 0x42, 0x60, 0xFF, 0x14]
SIMPLE_ISZERO = [0x60, 0x42, 0x15]
