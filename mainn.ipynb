# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_ADD, GAS, 0)

# %%
evm.run()

# %%
print(evm.stack)
# Out:
# 321 <first
