# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "comparisons-bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_LT, GAS, 0)
evm_two= EVM(SIMPLE_GT, GAS, 0)
evm_three= EVM(SIMPLE_SLT, GAS, 0)
evm_four= EVM(SIMPLE_SGT, GAS, 0)
evm_five= EVM(SIMPLE_EQ, GAS, 0)
evm_six= EVM(SIMPLE_ISZERO, GAS, 0)

# %%
evm.run()
evm_two.run()
# evm_three.run()
# evm_four.run()
evm_five.run()
evm_six.run()

# %%
print(evm.stack)
print(evm_two.stack)
print(evm_three.stack)
print(evm_four.stack)
print(evm_five.stack)
print(evm_six.stack)
# Out:
# 0 <first
# 1 <first
#
#
# 0 <first
# 0 <first
