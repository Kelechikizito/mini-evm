# %%
# %run utils.ipynb

notebooks = [
    "evm.ipynb",
    "bit-bytecode.ipynb"
]

import_notebooks(notebooks)

# %%
GAS = 21_000

# %%
evm = EVM(SIMPLE_BYTE, GAS, 0)
evm_two = EVM(SIMPLE_SHL, GAS, 0)
evm_three = EVM(SIMPLE_SHR, GAS, 0)
evm_four = EVM(SIMPLE_SAR, GAS, 0)

# %%
evm.run()
evm_two.run()
evm_three.run()
# evm_four.run()

# %%
print(evm.stack)
print(evm_two.stack)
print(evm_three.stack)
print(evm_four.stack)
# Out:
# 0 <first
# 264 <first
# 16 <first

# %%
import os
print(os.getcwd())
# Out:
# /Users/user/solidity-projects/mini-evm
